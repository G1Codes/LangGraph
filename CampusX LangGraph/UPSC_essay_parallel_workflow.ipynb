# %%
from langgraph.graph import StateGraph, START, END
from langchain_groq import ChatGroq
from typing import TypedDict, Annotated
from pydantic import BaseModel, Field
from dotenv import load_dotenv
import operator

# %%
model = ChatGroq(model="openai/gpt-oss-20b")

# %% [markdown]
# ### Structured Output:

# %%
class EvaluationSchema(BaseModel):
    feedback: str = Field(description='Detailed feedback for the essay')
    # Change int to float here
    score: float = Field(description='Score out of 10', ge=0, le=10)

# %%
structured_model = model.with_structured_output(EvaluationSchema)

# %% [markdown]
# Test:

# %%
essay = """India in the Age of AI
As the world enters a transformative era defined by artificial intelligence (AI), India stands at a critical juncture — one where it can either emerge as a global leader in AI innovation or risk falling behind in the technology race. The age of AI brings with it immense promise as well as unprecedented challenges, and how India navigates this landscape will shape its socio-economic and geopolitical future.

India's strengths in the AI domain are rooted in its vast pool of skilled engineers, a thriving IT industry, and a growing startup ecosystem. With over 5 million STEM graduates annually and a burgeoning base of AI researchers, India possesses the intellectual capital required to build cutting-edge AI systems. Institutions like IITs, IIITs, and IISc have begun fostering AI research, while private players such as TCS, Infosys, and Wipro are integrating AI into their global services. In 2020, the government launched the National AI Strategy (AI for All) with a focus on inclusive growth, aiming to leverage AI in healthcare, agriculture, education, and smart mobility.

One of the most promising applications of AI in India lies in agriculture, where predictive analytics can guide farmers on optimal sowing times, weather forecasts, and pest control. In healthcare, AI-powered diagnostics can help address India’s doctor-patient ratio crisis, particularly in rural areas. Educational platforms are increasingly using AI to personalize learning paths, while smart governance tools are helping improve public service delivery and fraud detection.

However, the path to AI-led growth is riddled with challenges. Chief among them is the digital divide. While metropolitan cities may embrace AI-driven solutions, rural India continues to struggle with basic internet access and digital literacy. The risk of job displacement due to automation also looms large, especially for low-skilled workers. Without effective skilling and re-skilling programs, AI could exacerbate existing socio-economic inequalities.

Another pressing concern is data privacy and ethics. As AI systems rely heavily on vast datasets, ensuring that personal data is used transparently and responsibly becomes vital. India is still shaping its data protection laws, and in the absence of a strong regulatory framework, AI systems may risk misuse or bias.

To harness AI responsibly, India must adopt a multi-stakeholder approach involving the government, academia, industry, and civil society. Policies should promote open datasets, encourage responsible innovation, and ensure ethical AI practices. There is also a need for international collaboration, particularly with countries leading in AI research, to gain strategic advantage and ensure interoperability in global systems.

India’s demographic dividend, when paired with responsible AI adoption, can unlock massive economic growth, improve governance, and uplift marginalized communities. But this vision will only materialize if AI is seen not merely as a tool for automation, but as an enabler of human-centered development.

In conclusion, India in the age of AI is a story in the making — one of opportunity, responsibility, and transformation. The decisions we make today will not just determine India’s AI trajectory, but also its future as an inclusive, equitable, and innovation-driven society."""

# %%
prompt = f'Evaluate the language quality of the following essay and provide a feedback and assign a score out of 10 \n {essay}'
response = structured_model.invoke(prompt)

# %%
response
# Out:
# EvaluationSchema(feedback='The essay is well‑structured, with a clear introduction, body paragraphs that cover strengths, applications, challenges, and recommendations, and a concise conclusion. The language is generally fluent and uses a formal register appropriate for an analytical piece. However, there are a few areas that could be improved:\n\n1. **Repetition and word choice** – Phrases such as “AI in India” appear frequently; varying the terminology (e.g., “India’s AI landscape,” “the country’s AI ecosystem”) would reduce redundancy.\n2. **Clarity and conciseness** – Some sentences are long and could be broken up for easier reading. For example, the sentence about the National AI Strategy could be split into two.\n3. **Specificity** – While the essay lists broad applications, providing a concrete example or statistic (e.g., a specific AI project in agriculture) would strengthen the argument.\n4. **Grammar and punctuation** – Minor issues such as missing commas (e.g., after “India’s doctor‑patient ratio crisis”) and inconsistent hyphenation (“AI‑powered,” “digital‑literacy”) should be corrected.\n5. **Tone consistency** – The essay occasionally shifts from formal to slightly informal phrasing (e.g., “the age of AI is a story in the making”). Maintaining a consistently formal tone will enhance credibility.\n\nOverall, the piece demonstrates strong analytical thinking and a solid grasp of the topic, with only modest language polish needed.', score=8.0)

# %%
response.feedback
# Out:
# 'The essay is well‑structured, with a clear introduction, body paragraphs that cover strengths, applications, challenges, and recommendations, and a concise conclusion. The language is generally fluent and uses a formal register appropriate for an analytical piece. However, there are a few areas that could be improved:\n\n1. **Repetition and word choice** – Phrases such as “AI in India” appear frequently; varying the terminology (e.g., “India’s AI landscape,” “the country’s AI ecosystem”) would reduce redundancy.\n2. **Clarity and conciseness** – Some sentences are long and could be broken up for easier reading. For example, the sentence about the National AI Strategy could be split into two.\n3. **Specificity** – While the essay lists broad applications, providing a concrete example or statistic (e.g., a specific AI project in agriculture) would strengthen the argument.\n4. **Grammar and punctuation** – Minor issues such as missing commas (e.g., after “India’s doctor‑patient ratio crisis”) and inconsistent hyphenation (“AI‑powered,” “digital‑literacy”) should be corrected.\n5. **Tone consistency** – The essay occasionally shifts from formal to slightly informal phrasing (e.g., “the age of AI is a story in the making”). Maintaining a consistently formal tone will enhance credibility.\n\nOverall, the piece demonstrates strong analytical thinking and a solid grasp of the topic, with only modest language polish needed.'

# %%
response.score
# Out:
# 8.0

# %% [markdown]
# ### State:

# %%
class UPSCState(TypedDict):

    essay: str
    language_feedback: str
    analysis_feedback: str
    clarity_feedback: str
    overall_feedback: str
    individual_scores: Annotated[list[int], operator.add]
    avg_score: float

# %% [markdown]
# ### Define Functions

# %%
def evaluate_language(state: UPSCState):

    prompt = f'Evaluate the language quality of the following essay and provide a feedback and assign a score out of 10 \n {state["essay"]}'
    output = structured_model.invoke(prompt)

    return {'language_feedback': output.feedback, 'individual_scores': [output.score]}

# %%
def evaluate_analysis(state: UPSCState):

    prompt = f'Evaluate the depth of analysis of the following essay and provide a feedback and assign a score out of 10 \n {state["essay"]}'
    output = structured_model.invoke(prompt)

    return {'analysis_feedback': output.feedback, 'individual_scores': [output.score]}

# %%
def evaluate_thought(state: UPSCState):

    prompt = f'Evaluate the clarity of thought of the following essay and provide a feedback and assign a score out of 10 \n {state["essay"]}'
    output = structured_model.invoke(prompt)

    return {'clarity_feedback': output.feedback, 'individual_scores': [output.score]}

# %%
def final_evaluation(state: UPSCState):

    # summary feedback
    prompt = f'Based on the following feedbacks create a summarized feedback \n language feedback - {state["language_feedback"]} \n depth of analysis feedback - {state["analysis_feedback"]} \n clarity of thought feedback - {state["clarity_feedback"]}'
    overall_feedback = model.invoke(prompt).content

    # avg calculate
    avg_score = sum(state['individual_scores'])/len(state['individual_scores'])

    return {'overall_feedback': overall_feedback, 'avg_score': avg_score}

# %% [markdown]
# ### Add nodes:

# %%
graph = StateGraph(UPSCState)

graph.add_node('evaluate_language', evaluate_language)
graph.add_node('evaluate_analysis', evaluate_analysis)
graph.add_node('evaluate_thought', evaluate_thought)
graph.add_node('final_evaluation', final_evaluation)

# edges
graph.add_edge(START, 'evaluate_language')
graph.add_edge(START, 'evaluate_analysis')
graph.add_edge(START, 'evaluate_thought')

graph.add_edge('evaluate_language', 'final_evaluation')
graph.add_edge('evaluate_analysis', 'final_evaluation')
graph.add_edge('evaluate_thought', 'final_evaluation')

graph.add_edge('final_evaluation', END)

workflow = graph.compile()
workflow

# %% [markdown]
# ## Test

# %%
essay2 = """India and AI Time

Now world change very fast because new tech call Artificial Intel… something (AI). India also want become big in this AI thing. If work hard, India can go top. But if no careful, India go back.

India have many good. We have smart student, many engine-ear, and good IT peoples. Big company like TCS, Infosys, Wipro already use AI. Government also do program “AI for All”. It want AI in farm, doctor place, school and transport.

In farm, AI help farmer know when to put seed, when rain come, how stop bug. In health, AI help doctor see sick early. In school, AI help student learn good. Government office use AI to find bad people and work fast.

But problem come also. First is many villager no have phone or internet. So AI not help them. Second, many people lose job because AI and machine do work. Poor people get more bad.

One more big problem is privacy. AI need big big data. Who take care? India still make data rule. If no strong rule, AI do bad.

India must all people together – govern, school, company and normal people. We teach AI and make sure AI not bad. Also talk to other country and learn from them.

If India use AI good way, we become strong, help poor and make better life. But if only rich use AI, and poor no get, then big bad thing happen.

So, in short, AI time in India have many hope and many danger. We must go right road. AI must help all people, not only some. Then India grow big and world say "good job India"."""

# %%
intial_state = {
    'essay': essay2
}

workflow.invoke(intial_state)
# Out:
# {'essay': 'India and AI Time\n\nNow world change very fast because new tech call Artificial Intel… something (AI). India also want become big in this AI thing. If work hard, India can go top. But if no careful, India go back.\n\nIndia have many good. We have smart student, many engine-ear, and good IT peoples. Big company like TCS, Infosys, Wipro already use AI. Government also do program “AI for All”. It want AI in farm, doctor place, school and transport.\n\nIn farm, AI help farmer know when to put seed, when rain come, how stop bug. In health, AI help doctor see sick early. In school, AI help student learn good. Government office use AI to find bad people and work fast.\n\nBut problem come also. First is many villager no have phone or internet. So AI not help them. Second, many people lose job because AI and machine do work. Poor people get more bad.\n\nOne more big problem is privacy. AI need big big data. Who take care? India still make data rule. If no strong rule, AI do bad.\n\nIndia must all people together – govern, school, company and normal people. We teach AI and make sure AI not bad. Also talk to other country and learn from them.\n\nIf India use AI good way, we become strong, help poor and make better life. But if only rich use AI, and poor no get, then big bad thing happen.\n\nSo, in short, AI time in India have many hope and many danger. We must go right road. AI must help all people, not only some. Then India grow big and world say "good job India".',
#  'language_feedback': 'The essay shows enthusiasm about India’s potential in AI, but the language quality is weak. There are frequent grammatical errors, inconsistent tense, and missing articles. The structure is loose, with many run‑on sentences and unclear phrasing (“new tech call Artificial Intel… something”). Word choice is often incorrect or informal (“engine‑ear”, “bad people”). Punctuation and capitalization are inconsistent. To improve, revise sentence structure, use proper vocabulary, and proofread for spelling and grammar. The overall message is clear, but the writing needs substantial editing to be coherent and professional.',
#  'analysis_feedback': 'The essay offers a broad overview of AI’s potential impact in India, touching on benefits in agriculture, health, education, and governance, as well as challenges such as digital divide, job displacement, and data privacy. However, the analysis remains largely surface‑level: it lacks concrete examples, data, or policy specifics, and it does not critically examine trade‑offs or propose nuanced solutions. The arguments are presented in a very general, sometimes vague way, and the essay does not engage deeply with the complexities of implementing AI in a diverse, large‑scale society. The structure is simple, and the language is informal, which further limits the depth of insight. Overall, the piece is a good introductory outline but falls short of a thorough analytical essay.\n\nScore: 4/10',
#  'clarity_feedback': 'The essay attempts to discuss India’s potential in AI but the ideas are presented in a very fragmented and informal manner. The overall structure is weak: there is no clear introduction, body, and conclusion, and the arguments jump abruptly from one point to another. Some sentences are incomplete or grammatically incorrect, which makes it hard to follow the author’s train of thought. The key points—India’s talent pool, existing AI initiatives, potential benefits in agriculture, healthcare, education, and governance, and the challenges of connectivity, employment, and privacy—are all mentioned, but they are not linked coherently. A more logical flow with topic sentences, supporting details, and transitions would improve clarity. The essay also repeats ideas and uses vague language (“big bad thing”, “AI need big big data”) that detracts from its persuasive power. Overall, while the intent is clear, the execution lacks clarity and coherence.\n\nScore: 4/10',
#  'overall_feedback': '**Overall Assessment – 4/10**\n\n| Aspect | What’s Wrong | Suggested Improvements |\n|--------|--------------|------------------------|\n| **Language & Mechanics** | • Frequent grammatical mistakes, tense shifts, missing articles.<br>• Run‑on sentences and unclear phrasing (“new tech call Artificial Intel… something”).<br>• Informal/inaccurate word choice (“engine‑ear”, “bad people”).<br>• Inconsistent punctuation & capitalization. | • Proofread for spelling, grammar and tense consistency.<br>• Break long sentences into clear, concise ones.<br>• Use a style guide (e.g., AP or Chicago) for proper article use and capitalization.<br>• Replace informal slang with precise academic vocabulary. |\n| **Depth of Analysis** | • Only a broad overview of AI benefits (agriculture, health, education, governance).<br>• Lacks concrete examples, statistics, or policy details.<br>• No critical discussion of trade‑offs or nuanced solutions.<br>• Arguments remain vague and surface‑level. | • Anchor each claim with data, case studies, or expert quotes.<br>• Analyze pros/cons, e.g., job displacement vs. new skill demands.<br>• Propose specific policy recommendations or implementation steps.<br>• Use evidence to support each point, not just general statements. |\n| **Clarity & Structure** | • No clear introduction, body, or conclusion.<br>• Ideas jump abruptly; sentences are incomplete or grammatically wrong.<br>• Key points are mentioned but not linked; repetition and vague language (“big bad thing”, “AI need big big data”). | • Start with a thesis statement and roadmap.<br>• Organize into logical sections: Introduction → Benefits → Challenges → Recommendations → Conclusion.<br>• Use topic sentences, supporting details, and transitions.<br>• Avoid repetition; keep language precise and focused. |\n\n### Quick Action Plan\n1. **Draft a new outline** with clear headings and sub‑headings.  \n2. **Write one paragraph per section**, then revise for clarity and conciseness.  \n3. **Insert evidence** (statistics, reports, pilot projects) after each claim.  \n4. **Run a grammar checker** and manually proofread for tone and consistency.  \n5. **Peer‑review** or have a mentor read for flow and logical coherence.\n\nBy tightening the language, enriching the analysis with data, and restructuring the essay, the piece will transform from a general overview into a compelling, professional argument about India’s AI future.',
#  'individual_scores': [4.0, 4.0, 4.0],
#  'avg_score': 4.0}

# %%
essay = """India in the Age of AI
As the world enters a transformative era defined by artificial intelligence (AI), India stands at a critical juncture — one where it can either emerge as a global leader in AI innovation or risk falling behind in the technology race. The age of AI brings with it immense promise as well as unprecedented challenges, and how India navigates this landscape will shape its socio-economic and geopolitical future.

India's strengths in the AI domain are rooted in its vast pool of skilled engineers, a thriving IT industry, and a growing startup ecosystem. With over 5 million STEM graduates annually and a burgeoning base of AI researchers, India possesses the intellectual capital required to build cutting-edge AI systems. Institutions like IITs, IIITs, and IISc have begun fostering AI research, while private players such as TCS, Infosys, and Wipro are integrating AI into their global services. In 2020, the government launched the National AI Strategy (AI for All) with a focus on inclusive growth, aiming to leverage AI in healthcare, agriculture, education, and smart mobility.

One of the most promising applications of AI in India lies in agriculture, where predictive analytics can guide farmers on optimal sowing times, weather forecasts, and pest control. In healthcare, AI-powered diagnostics can help address India’s doctor-patient ratio crisis, particularly in rural areas. Educational platforms are increasingly using AI to personalize learning paths, while smart governance tools are helping improve public service delivery and fraud detection.

However, the path to AI-led growth is riddled with challenges. Chief among them is the digital divide. While metropolitan cities may embrace AI-driven solutions, rural India continues to struggle with basic internet access and digital literacy. The risk of job displacement due to automation also looms large, especially for low-skilled workers. Without effective skilling and re-skilling programs, AI could exacerbate existing socio-economic inequalities.

Another pressing concern is data privacy and ethics. As AI systems rely heavily on vast datasets, ensuring that personal data is used transparently and responsibly becomes vital. India is still shaping its data protection laws, and in the absence of a strong regulatory framework, AI systems may risk misuse or bias.

To harness AI responsibly, India must adopt a multi-stakeholder approach involving the government, academia, industry, and civil society. Policies should promote open datasets, encourage responsible innovation, and ensure ethical AI practices. There is also a need for international collaboration, particularly with countries leading in AI research, to gain strategic advantage and ensure interoperability in global systems.

India’s demographic dividend, when paired with responsible AI adoption, can unlock massive economic growth, improve governance, and uplift marginalized communities. But this vision will only materialize if AI is seen not merely as a tool for automation, but as an enabler of human-centered development.

In conclusion, India in the age of AI is a story in the making — one of opportunity, responsibility, and transformation. The decisions we make today will not just determine India’s AI trajectory, but also its future as an inclusive, equitable, and innovation-driven society."""

# %%
intial_state = {
    'essay': essay
}

workflow.invoke(intial_state)
# Out:
# {'essay': "India in the Age of AI\nAs the world enters a transformative era defined by artificial intelligence (AI), India stands at a critical juncture — one where it can either emerge as a global leader in AI innovation or risk falling behind in the technology race. The age of AI brings with it immense promise as well as unprecedented challenges, and how India navigates this landscape will shape its socio-economic and geopolitical future.\n\nIndia's strengths in the AI domain are rooted in its vast pool of skilled engineers, a thriving IT industry, and a growing startup ecosystem. With over 5 million STEM graduates annually and a burgeoning base of AI researchers, India possesses the intellectual capital required to build cutting-edge AI systems. Institutions like IITs, IIITs, and IISc have begun fostering AI research, while private players such as TCS, Infosys, and Wipro are integrating AI into their global services. In 2020, the government launched the National AI Strategy (AI for All) with a focus on inclusive growth, aiming to leverage AI in healthcare, agriculture, education, and smart mobility.\n\nOne of the most promising applications of AI in India lies in agriculture, where predictive analytics can guide farmers on optimal sowing times, weather forecasts, and pest control. In healthcare, AI-powered diagnostics can help address India’s doctor-patient ratio crisis, particularly in rural areas. Educational platforms are increasingly using AI to personalize learning paths, while smart governance tools are helping improve public service delivery and fraud detection.\n\nHowever, the path to AI-led growth is riddled with challenges. Chief among them is the digital divide. While metropolitan cities may embrace AI-driven solutions, rural India continues to struggle with basic internet access and digital literacy. The risk of job displacement due to automation also looms large, especially for low-skilled workers. Without effective skilling and re-skilling programs, AI could exacerbate existing socio-economic inequalities.\n\nAnother pressing concern is data privacy and ethics. As AI systems rely heavily on vast datasets, ensuring that personal data is used transparently and responsibly becomes vital. India is still shaping its data protection laws, and in the absence of a strong regulatory framework, AI systems may risk misuse or bias.\n\nTo harness AI responsibly, India must adopt a multi-stakeholder approach involving the government, academia, industry, and civil society. Policies should promote open datasets, encourage responsible innovation, and ensure ethical AI practices. There is also a need for international collaboration, particularly with countries leading in AI research, to gain strategic advantage and ensure interoperability in global systems.\n\nIndia’s demographic dividend, when paired with responsible AI adoption, can unlock massive economic growth, improve governance, and uplift marginalized communities. But this vision will only materialize if AI is seen not merely as a tool for automation, but as an enabler of human-centered development.\n\nIn conclusion, India in the age of AI is a story in the making — one of opportunity, responsibility, and transformation. The decisions we make today will not just determine India’s AI trajectory, but also its future as an inclusive, equitable, and innovation-driven society.",
#  'language_feedback': 'The essay demonstrates a clear, organized structure and uses a formal register appropriate for an analytical piece. The prose is generally fluent, with varied sentence lengths and a good range of vocabulary. However, there are a few areas for improvement:\n\n1. **Consistency and Precision** – Some statements are vague or could be more precise (e.g., “AI for All” strategy is mentioned without a citation, and the phrase “AI for All” is not italicized or quoted consistently). Adding specific data points or references would strengthen credibility.\n2. **Grammar and Punctuation** – Minor errors such as missing commas (e.g., after “India’s doctor‑patient ratio crisis”), inconsistent hyphenation (“low‑skilled”), and a missing article (“the National AI Strategy”) affect readability.\n3. **Repetition and Word Choice** – The essay occasionally repeats ideas (“AI can guide farmers” and “AI can help farmers”), and some word choices feel generic (“unprecedented challenges”). More varied diction and active verbs would enhance engagement.\n4. **Paragraph Flow** – While each paragraph is cohesive, transitions between some sections are abrupt. Using connective phrases (“Moreover,” “In addition,” “Conversely”) could improve the logical flow.\n5. **Tone and Audience** – The tone is largely formal, but occasional colloquial phrasing (“in the absence of a strong regulatory framework”) could be refined to maintain a consistently professional voice.\n\nOverall, the essay is well‑structured and presents a balanced analysis. Addressing these points would elevate it from competent to excellent.\n',
#  'analysis_feedback': "The essay offers a broad overview of India's potential and challenges in the AI era, touching on human capital, key sectors, policy initiatives, and ethical concerns. It correctly identifies strengths—such as a large STEM workforce and a growing startup ecosystem—and outlines concrete applications in agriculture, healthcare, education, and governance. However, the analysis remains largely descriptive and lacks depth in several areas.\n\n1. **Evidence and Data**: While the essay cites figures like 5\u202fmillion STEM graduates, it does not provide recent statistics, trends, or comparative data to benchmark India against global leaders. Quantitative evidence would strengthen arguments about AI adoption rates, investment volumes, or productivity gains.\n\n2. **Critical Evaluation**: The discussion of challenges (digital divide, job displacement, data privacy) is surface‑level. It would benefit from deeper exploration of root causes, potential policy levers, and case studies that illustrate the impact of AI on specific communities. For instance, the claim about rural internet access could be supported with penetration statistics or examples of successful rural AI pilots.\n\n3. **Policy Nuances**: The mention of the National AI Strategy is appropriate, but the essay does not analyze its implementation status, funding mechanisms, or alignment with existing digital infrastructure plans. A more nuanced critique of policy gaps and recommendations would show a higher level of analysis.\n\n4. **Ethical and Societal Dimensions**: The brief nod to data privacy and bias is a good start, yet the essay misses an opportunity to discuss frameworks like explainability, fairness metrics, or India’s evolving data protection laws. An exploration of how these ethical considerations intersect with AI’s economic promises would deepen the analysis.\n\n5. **Strategic Outlook**: The concluding vision is optimistic but lacks a concrete roadmap. Discussing timelines, investment targets, or collaboration models with global AI hubs would provide a clearer sense of feasibility.\n\nOverall, the essay demonstrates a solid grasp of the topic but would benefit from richer evidence, deeper critical assessment, and more detailed policy recommendations. The depth of analysis is moderate, appropriate for an introductory piece but not for a comprehensive policy brief.\n",
#  'clarity_feedback': 'The essay presents a clear, logical structure that guides the reader through India’s potential and challenges in AI. The opening sets a strong context, followed by distinct sections on strengths, applications, obstacles, and solutions. Each paragraph focuses on a single idea and uses concrete examples (agriculture, healthcare, education) to illustrate the benefits. The concluding remarks tie the discussion back to broader societal goals. Overall, the argument is coherent and easy to follow.\n\nAreas for improvement: 1) Some sentences are long and could be split for better readability. 2) The transition between the challenges and solutions could be smoother by explicitly linking them. 3) The essay could benefit from a brief mention of specific policy initiatives or international partnerships to strengthen the call for collaboration. 4) A concluding sentence that reiterates the thesis in a memorable way would leave a stronger final impression.',
#  'overall_feedback': '**Overall Summary**\n\nThe essay is a solid, well‑structured analysis that convincingly outlines India’s AI opportunities and challenges. It shows clear logical flow, uses concrete sector examples, and maintains a formal tone. To elevate it to an excellent piece, focus on the following areas:\n\n| Aspect | Strengths | Key Improvements |\n|--------|-----------|------------------|\n| **Language & Style** | Clear, organized prose; varied sentence lengths; good vocabulary | • Add precise data and citations (e.g., “AI for All” strategy). <br>• Fix minor grammar/punctuation (commas, hyphens, articles). <br>• Reduce repetition and use more active, varied diction. <br>• Smooth transitions with connective phrases. <br>• Remove occasional colloquialisms to keep a consistently professional voice. |\n| **Depth of Analysis** | Broad overview of strengths, sectors, policy, ethics | • Incorporate recent, comparative statistics to back claims. <br>• Provide deeper critical evaluation of challenges (root causes, policy levers, case studies). <br>• Analyze policy implementation, funding, and alignment with existing infrastructure. <br>• Expand on ethical frameworks (explainability, fairness, data protection). <br>• Offer a concrete, time‑based roadmap (investment targets, partnerships). |\n| **Clarity of Thought** | Logical structure; distinct sections; concrete examples | • Shorten long sentences for readability. <br>• Explicitly link challenges to solutions for smoother flow. <br>• Mention specific policy initiatives or international collaborations. <br>• End with a memorable concluding sentence that restates the thesis. |\n\n**Bottom line:** The essay already demonstrates competence. Strengthening evidence, deepening critique, polishing language, and tightening transitions will transform it from a solid overview into an outstanding, policy‑ready analysis.',
#  'individual_scores': [7.0, 8.0, 9.0],
#  'avg_score': 8.0}
